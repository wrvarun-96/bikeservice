# %% [markdown]
# # Capital BikeShare

# %%
import pandas as pd

trip=pd.read_csv(r'C:\Users\W R VARUN\Desktop\Data Science\MentorBoxCo\Trip\201908-tripdata.csv')
trip
# Out:
#         Duration        Start date          End date  Start station number  \
# 0            357  01-08-2019 00:00  01-08-2019 00:06                 31117
# 1           1100  01-08-2019 00:01  01-08-2019 00:20                 31407
# 2           1406  01-08-2019 00:04  01-08-2019 00:27                 31407
# 3           3667  01-08-2019 00:05  01-08-2019 01:06                 31907
# 4            282  01-08-2019 00:05  01-08-2019 00:09                 31201
# ...          ...               ...               ...                   ...
# 360039       228  31-08-2019 23:57  01-09-2019 00:01                 31102
# 360040      1587  31-08-2019 23:57  01-09-2019 00:23                 31256
# 360041      2187  31-08-2019 23:57  01-09-2019 00:34                 31288
# 360042      4473  31-08-2019 23:58  01-09-2019 01:13                 31129
# 360043       537  31-08-2019 23:59  01-09-2019 00:08                 31035
#
#                         Start station  End station number  \
# ...

# %%
import pandas_profiling
pandas_profiling.ProfileReport(trip)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-11 18:21:20.266817&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360044 entries, 0 to 360043
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Duration              360044 non-null  int64
#  1   Start date            360044 non-null  object
#  2   End date              360044 non-null  object
#  3   Start station number  360044 non-null  int64
#  4   Start station         360044 non-null  object
#  5   End station number    360044 non-null  int64
#  6   End station           360044 non-null  object
#  7   Bike number           360044 non-null  object
#  8   Member type           360044 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 24.7+ MB

# %%
trip.isnull().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %% [markdown]
# ### Converting 'Object type to Datetime type'

# %%
trip['Start date']=pd.to_datetime(trip['Start date'],format='%d-%m-%Y %H:%M')
trip['End date']=pd.to_datetime(trip['End date'],format='%d-%m-%Y %H:%M')
trip
# Out:
#         Duration          Start date            End date  \
# 0            357 2019-08-01 00:00:00 2019-08-01 00:06:00
# 1           1100 2019-08-01 00:01:00 2019-08-01 00:20:00
# 2           1406 2019-08-01 00:04:00 2019-08-01 00:27:00
# 3           3667 2019-08-01 00:05:00 2019-08-01 01:06:00
# 4            282 2019-08-01 00:05:00 2019-08-01 00:09:00
# ...          ...                 ...                 ...
# 360039       228 2019-08-31 23:57:00 2019-09-01 00:01:00
# 360040      1587 2019-08-31 23:57:00 2019-09-01 00:23:00
# 360041      2187 2019-08-31 23:57:00 2019-09-01 00:34:00
# 360042      4473 2019-08-31 23:58:00 2019-09-01 01:13:00
# 360043       537 2019-08-31 23:59:00 2019-09-01 00:08:00
#
#         Start station number                  Start station  \
# 0                      31117           15th & Euclid St  NW
# 1                      31407      14th St & Colorado Ave NW
# 2                      31407      14th St & Colorado Ave NW
# ...

# %% [markdown]
# ### 1)Most preffered top 15 Start_Station_Number
# ### 2)Top 15 usual End_Station_Number

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
sns.barplot(x=trip['Start station number'].value_counts(ascending=False).head(15).index,
            y=trip['Start station number'].value_counts(ascending=False).head(15),
            order=trip['Start station number'].value_counts(ascending=False).head(15).index)
plt.xlabel('Start station number')
plt.ylabel('Count')

plt.figure(figsize=(16,6))
sns.barplot(x=trip['End station number'].value_counts(ascending=False).head(15).index,
            y=trip['End station number'].value_counts(ascending=False).head(15),
            order=trip['End station number'].value_counts(ascending=False).head(15).index)
plt.xlabel('End station number')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### 1)Least prefferd Start_Station_Number
# ### 2)Least End_Station_Number

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=trip['Start station number'].value_counts(ascending=False).tail(15).index,
            y=trip['Start station number'].value_counts(ascending=False).tail(15),
            order=trip['Start station number'].value_counts(ascending=False).tail(15).index)
plt.xlabel('Start station number')
plt.ylabel('Count')

plt.figure(figsize=(16,6))
sns.barplot(x=trip['End station number'].value_counts(ascending=False).tail(15).index,
            y=trip['End station number'].value_counts(ascending=False).tail(15),
            order=trip['End station number'].value_counts(ascending=False).tail(15).index)
plt.xlabel('End station number')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
print(trip['Start station'].value_counts())
trip['End station'].value_counts()
# Out:
# Columbus Circle / Union Station                          5561
# Lincoln Memorial                                         4535
# Henry Bacon Dr & Lincoln Memorial Circle NW              4408
# 15th & P St NW                                           3868
# 4th St & Madison Dr NW                                   3805
#                                                          ...
# Joliet St & MLK Ave SW/Bald Eagle Rec Ctr                   5
# Campus Commons                                              4
# Broschart & Blackwell Rd                                    2
# North Shore & Cameron Crescent Dr/Crescent Apartments       1
# Crabbs Branch Way & Redland Rd                              1
# Name: Start station, Length: 565, dtype: int64
# Columbus Circle / Union Station                6002
# Henry Bacon Dr & Lincoln Memorial Circle NW    4507
# Lincoln Memorial                               4482
# 15th & P St NW                                 4184
# ...

# %%
trip['Start station'].value_counts(ascending=False)
# Out:
# Columbus Circle / Union Station                          5561
# Lincoln Memorial                                         4535
# Henry Bacon Dr & Lincoln Memorial Circle NW              4408
# 15th & P St NW                                           3868
# 4th St & Madison Dr NW                                   3805
#                                                          ...
# Joliet St & MLK Ave SW/Bald Eagle Rec Ctr                   5
# Campus Commons                                              4
# Broschart & Blackwell Rd                                    2
# North Shore & Cameron Crescent Dr/Crescent Apartments       1
# Crabbs Branch Way & Redland Rd                              1
# Name: Start station, Length: 565, dtype: int64

# %% [markdown]
# ### Longest and Shortest Time of Trips

# %%
import datetime

maxs=trip['Duration'].max()
mins=trip['Duration'].min()
more_used=trip.loc[trip['Duration']==maxs,'Member type'].value_counts().index[0]
less_used=trip.loc[trip['Duration']==mins,'Member type'].value_counts().index[0]

print('Highest time used is {} by {} \nLowest time used is {} by {}'.format(datetime.timedelta(seconds=maxs),more_used,
                                                                      datetime.timedelta(seconds=mins),less_used))
# Out:
# Highest time used is 23:52:28 by Casual
# Lowest time used is 0:01:00 by Member

# %% [markdown]
# ### Reducing more from Start and End Dates

# %%
trip['Start_Day']=trip['Start date'].dt.day
trip['Start_Month']=trip['Start date'].dt.month
trip['Start_Hour']=trip['Start date'].dt.hour
trip['Start_Min']=trip['Start date'].dt.minute
trip['Start_week']=trip['Start date'].dt.dayofweek

trip['End_Day']=trip['End date'].dt.day
trip['End_Month']=trip['End date'].dt.month
trip['End_Hour']=trip['End date'].dt.hour
trip['End_Min']=trip['End date'].dt.minute
trip['End_week']=trip['End date'].dt.dayofweek

# %%
trip
# Out:
#         Duration          Start date            End date  \
# 0            357 2019-08-01 00:00:00 2019-08-01 00:06:00
# 1           1100 2019-08-01 00:01:00 2019-08-01 00:20:00
# 2           1406 2019-08-01 00:04:00 2019-08-01 00:27:00
# 3           3667 2019-08-01 00:05:00 2019-08-01 01:06:00
# 4            282 2019-08-01 00:05:00 2019-08-01 00:09:00
# ...          ...                 ...                 ...
# 360039       228 2019-08-31 23:57:00 2019-09-01 00:01:00
# 360040      1587 2019-08-31 23:57:00 2019-09-01 00:23:00
# 360041      2187 2019-08-31 23:57:00 2019-09-01 00:34:00
# 360042      4473 2019-08-31 23:58:00 2019-09-01 01:13:00
# 360043       537 2019-08-31 23:59:00 2019-09-01 00:08:00
#
#         Start station number                  Start station  \
# 0                      31117           15th & Euclid St  NW
# 1                      31407      14th St & Colorado Ave NW
# 2                      31407      14th St & Colorado Ave NW
# ...

# %%
trip.insert(0,'Start Latitude','NaN')
trip.insert(0,'Start Longitude','NaN')
trip.insert(0,'End Latitude',"NaN")
trip.insert(0,'End Longitude','NaN')

# %%
#Getting latitude and longitude of locations

from geopy.geocoders import Nominatim

geolocator=Nominatim(user_agent='Varun')
for i in trip['Start station'].unique():
    location=geolocator.geocode(i)
    ind=[]
    ind.append(trip[trip['Start station']==i].index.tolist())
    try:
        for j in ind:
            trip['Start Latitude'][j]=location.latitude
            trip['Start Longitude'][j]=location.longitude
    except:
        pass
# Out:
# C:\Users\W R VARUN\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\W R VARUN\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
geolocator=Nominatim(user_agent='Varun')

for z in trip['End station'].unique():
    location1=geolocator.geocode(z)
    ind=[]
    ind.append(trip[trip['Start station']==z].index.tolist())
    try:
        for w in ind:
            trip['End Latitude'][w]=location1.latitude
            trip['End Longitude'][w]=location1.longitude
    except:
        pass
# Out:
# C:\Users\W R VARUN\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\W R VARUN\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
trip.isnull().sum()
# Out:
# End Longitude           0
# End Latitude            0
# Start Longitude         0
# Start Latitude          0
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# Start_Day               0
# Start_Month             0
# Start_Hour              0
# Start_Min               0
# Start_week              0
# End_Day                 0
# End_Month               0
# End_Hour                0
# End_Min                 0
# End_week                0
# dtype: int64

# %%
trip=trip.drop(['Start date','End date'],axis=1)

# %%
trip_do=trip.copy()

# %%
Q1=trip.quantile(0.25)       
#print(Q1)
Q3=trip.quantile(0.75)
#print(Q3)
IQR=Q3-Q1
#print(IQR)
trip=trip[~((trip<(Q1-1.5*IQR)) | (trip>(Q3+1.5*IQR)))]
print(trip.isnull().sum())
trip
# Out:
# End Longitude               0
# End Latitude                0
# Start Longitude             0
# Start Latitude              0
# Duration                24630
# Start station number    10057
# Start station               0
# End station number       9600
# End station                 0
# Bike number                 0
# Member type                 0
# Start_Day                   0
# Start_Month                 0
# Start_Hour                  0
# Start_Min                   0
# Start_week                  0
# End_Day                     0
# End_Month                  96
# End_Hour                    0
# End_Min                     0
# End_week                    0
# dtype: int64
#        End Longitude End Latitude Start Longitude Start Latitude  Duration  \
# 0           -77.0351      38.9234        -77.0351        38.9234     357.0
# 1           -77.0329      38.9564        -77.0329        38.9564    1100.0
# 2           -77.0329      38.9564        -77.0329        38.9564    1406.0
# ...

# %%
##Filling Null Values
for i in trip['Start station'].unique():
    start=trip.loc[trip['Start station']==i,'Start station number'].mode()
    trip.loc[(trip['Start station']==i)&(trip['Start station number']==1),'Start station number']=start
    
    end=trip.loc[trip['End station']==i,'End station number'].mode()
    trip.loc[(trip['End station']==i)&(trip['End station number']==1),'End station number']=end

# %%
##Filling Null Values
null_ind=trip[trip['Duration'].isnull()].index.tolist()
for i in null_ind:
    start_pt=trip['Start station'][i]
    end_pt=trip['End station'][i]
    
    trip['Duration'][i]=trip.loc[(trip['Start station']==start_pt)&(trip['End station']==end_pt),'Duration'].mean()
# Out:
# C:\Users\W R VARUN\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
trip_finals=trip.copy()

# %%
trip.isnull().sum()
#Their is still null values so have to look into it furthur.
# Out:
# End Longitude               0
# End Latitude                0
# Start Longitude             0
# Start Latitude              0
# Duration                 3970
# Start station number    10057
# Start station               0
# End station number       9600
# End station                 0
# Bike number                 0
# Member type                 0
# Start_Day                   0
# Start_Month                 0
# Start_Hour                  0
# Start_Min                   0
# Start_week                  0
# End_Day                     0
# End_Month                  96
# End_Hour                    0
# End_Min                     0
# End_week                    0
# dtype: int64

# %%
trip[trip['Start station number'].isnull()].index.tolist()
# Out:
# [49,
#  73,
#  197,
#  285,
#  353,
#  387,
#  406,
#  438,
#  449,
#  462,
#  473,
#  504,
#  507,
#  515,
#  572,
#  609,
#  674,
#  755,
#  772,
#  790,
#  794,
#  880,
#  971,
#  991,
#  1004,
#  1027,
#  1032,
#  1076,
#  1079,
#  1173,
#  1179,
#  1232,
#  1254,
#  1261,
#  1274,
#  1310,
#  1322,
#  1329,
#  1367,
#  1426,
#  1430,
#  1442,
#  1450,
#  1516,
#  1519,
#  1529,
#  1592,
#  1615,
#  1678,
#  1714,
#  1719,
#  1729,
#  1751,
#  1755,
#  1759,
#  1777,
#  1789,
#  1843,
#  1869,
#  1906,
#  1968,
#  1971,
#  1982,
#  2003,
#  2034,
#  2051,
#  2098,
#  2191,
#  2198,
#  2261,
#  2263,
#  2274,
#  2288,
#  2358,
#  2418,
#  2432,
#  2448,
#  2450,
#  2518,
#  2535,
#  2543,
#  2578,
#  2600,
#  2601,
#  2647,
#  2650,
#  2680,
#  2693,
#  2711,
#  2717,
#  2733,
#  2747,
#  2800,
#  2852,
#  2897,
#  2898,
#  2912,
#  2924,
#  2942,
#  3023,
#  3044,
#  3186,
#  3190,
#  3221,
#  3253,
#  3352,
#  3382,
#  3532,
#  3597,
#  3624,
#  3633,
#  3640,
#  3645,
#  3660,
# ...

# %%
print(len(trip['Start station'].unique()))
print(len(trip['Start station number'].unique()))
print(len(trip['End station'].unique()))
print(len(trip['End station number'].unique()))

#Their is difference of lengths which may affect our model
# Out:
# 565
# 423
# 565
# 422

# %%
#Seeing why for "Start station number" why number is not their
trip.iloc[507]
# Out:
# End Longitude                                          -77.0531
# End Latitude                                            39.0433
# Start Longitude                                        -77.0531
# Start Latitude                                          39.0433
# Duration                                                    160
# Start station number                                        NaN
# Start station                         Grandview & Blueridge Ave
# End station number                                          NaN
# End station             Wheaton Metro / Georgia Ave & Reedie Dr
# Bike number                                              W21327
# Member type                                              Member
# Start_Day                                                     1
# Start_Month                                                   8
# Start_Hour                                                    6
# Start_Min                                                    42
# ...

# %%
#Checking for random staion from lot
print(trip.loc[trip['Start station']=='Grandview & Blueridge Ave','Start station number'])
print("**************************************************************")
print(trip.loc[trip['End station']=='Wheaton Metro / Georgia Ave & Reedie Dr','End station number'])

#That Station is not recored here so we dont know the value so have to drop those rows
# Out:
# 507      NaN
# 1274     NaN
# 13367    NaN
# 13637    NaN
# 25659    NaN
# 25849    NaN
# 37783    NaN
# 49033    NaN
# 61234    NaN
# 73120    NaN
# 73272    NaN
# 84355    NaN
# 84460    NaN
# 97063    NaN
# 107409   NaN
# 119734   NaN
# 146989   NaN
# 157330   NaN
# 157935   NaN
# 158134   NaN
# 170147   NaN
# 170470   NaN
# 181160   NaN
# 181250   NaN
# 193501   NaN
# 193827   NaN
# 198782   NaN
# 204555   NaN
# 206013   NaN
# 214182   NaN
# 224842   NaN
# 233481   NaN
# 233882   NaN
# 238821   NaN
# 245143   NaN
# 245466   NaN
# 246014   NaN
# 256991   NaN
# 257210   NaN
# 258804   NaN
# 289558   NaN
# 298256   NaN
# 301071   NaN
# 313185   NaN
# 313739   NaN
# 324526   NaN
# 324716   NaN
# 337443   NaN
# 349337   NaN
# Name: Start station number, dtype: float64
# **************************************************************
# 507      NaN
# 1274     NaN
# 13367    NaN
# 13637    NaN
# 25659    NaN
#           ..
# 337443   NaN
# 349337   NaN
# 351036   NaN
# 351984   NaN
# ...

# %%
#Checking for duration column
null_duration=trip[trip['Duration'].isnull()].index.tolist()
null_duration
# Out:
# [406,
#  877,
#  931,
#  991,
#  1055,
#  1170,
#  1452,
#  1625,
#  1763,
#  1778,
#  2016,
#  2185,
#  2214,
#  3506,
#  3757,
#  3759,
#  3796,
#  3895,
#  3909,
#  3921,
#  3923,
#  4304,
#  4314,
#  4332,
#  4527,
#  4587,
#  4593,
#  4599,
#  4702,
#  4709,
#  4742,
#  4764,
#  5044,
#  5382,
#  5458,
#  5465,
#  5644,
#  5713,
#  5716,
#  5725,
#  5727,
#  5737,
#  5739,
#  5775,
#  5819,
#  5820,
#  5822,
#  5834,
#  5850,
#  5985,
#  5986,
#  6018,
#  6026,
#  6030,
#  6293,
#  6294,
#  6554,
#  6558,
#  6669,
#  6670,
#  6671,
#  6677,
#  6865,
#  6866,
#  7085,
#  7251,
#  7354,
#  7366,
#  7514,
#  7949,
#  7972,
#  7979,
#  8087,
#  8094,
#  8328,
#  8333,
#  8374,
#  8408,
#  8428,
#  8478,
#  8949,
#  9517,
#  9519,
#  9661,
#  9925,
#  9940,
#  10047,
#  10059,
#  10252,
#  10255,
#  10257,
#  10312,
#  10401,
#  10452,
#  10578,
#  10811,
#  10815,
#  10827,
#  11028,
#  11067,
#  11098,
#  11168,
#  11272,
#  11354,
#  11830,
#  11834,
#  11943,
#  12092,
#  12716,
# ...

# %%
trip_final=trip.copy()

# %%
trip.isnull().sum()
# Out:
# End Longitude               0
# End Latitude                0
# Start Longitude             0
# Start Latitude              0
# Duration                 3970
# Start station number    10057
# Start station               0
# End station number       9600
# End station                 0
# Bike number                 0
# Member type                 0
# Start_Day                   0
# Start_Month                 0
# Start_Hour                  0
# Start_Min                   0
# Start_week                  0
# End_Day                     0
# End_Month                  96
# End_Hour                    0
# End_Min                     0
# End_week                    0
# dtype: int64

# %%
#Checking still why dint it capture
trip.loc[(trip['Start station']=='Eads St & 12th St S')&(trip['End station']=='8th & H St NW'),'Duration'].mean()

#It has given null because their is no travel in this.So its better we drop these rows
# Out:
# nan

# %%
trip=trip.dropna()

# %%
trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344970 entries, 0 to 360030
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   End Longitude         344970 non-null  object
#  1   End Latitude          344970 non-null  object
#  2   Start Longitude       344970 non-null  object
#  3   Start Latitude        344970 non-null  object
#  4   Duration              344970 non-null  float64
#  5   Start station number  344970 non-null  float64
#  6   Start station         344970 non-null  object
#  7   End station number    344970 non-null  float64
#  8   End station           344970 non-null  object
#  9   Bike number           344970 non-null  object
#  10  Member type           344970 non-null  object
#  11  Start_Day             344970 non-null  int64
#  12  Start_Month           344970 non-null  int64
#  13  Start_Hour            344970 non-null  int64
# ...

# %%
trip['End Longitude']=trip['End Longitude'].astype('float64')
trip['End Latitude']=trip['End Latitude'].astype('float64')
trip['Start Longitude']=trip['Start Longitude'].astype('float64')
trip['Start Latitude']=trip['Start Latitude'].astype('float64')

# %%
import numpy as np

trip['Start Latitude']=np.radians(trip['Start Latitude'])
trip['Start Longitude']=np.radians(trip['Start Longitude'])
trip['End Latitude']=np.radians(trip['End Latitude'])
trip['End Longitude']=np.radians(trip['End Longitude'])

# %%
trip=trip.dropna()

# %%
trip
# Out:
#         End Longitude  End Latitude  Start Longitude  Start Latitude  \
# 0           -1.344516      0.679341        -1.344516        0.679341
# 1           -1.344479      0.679918        -1.344479        0.679918
# 2           -1.344479      0.679918        -1.344479        0.679918
# 3           -1.356632      0.694205        -1.356632        0.694205
# 4           -1.344505      0.679105        -1.344505        0.679105
# ...               ...           ...              ...             ...
# 360009      -1.344772      0.678865        -1.344772        0.678865
# 360012      -1.344292      0.679033        -1.344292        0.679033
# 360014      -1.344313      0.679424        -1.344313        0.679424
# 360016      -1.344001      0.679033        -1.344001        0.679033
# 360030      -1.344466      0.679432        -1.344466        0.679432
#
#            Duration  Start station number                      Start station  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,6))
sns.lineplot(x=trip['Start_Day'],y=trip['Duration'])
plt.show()

# %% [markdown]
# ## Usually its the "2nd" or "3rd" day of every week trip time or duration is more. And least time used in on weekends.

# %%
from sklearn.preprocessing import LabelEncoder

label=LabelEncoder()
for i in ['Start station number','End station number','Bike number']:
    trip[i]=label.fit_transform(trip[i])

# %%
#trip=trip.drop(['Start station','End station'],axis=1)
trip=trip.drop(['Start station number','End station number','Bike number','Start station','End station'],axis=1)
#trip=trip.drop(['End Longitude','End Latitude','Start Longitude','Start Latitude'],axis=1)
trip.isnull().sum()
# Out:
# End Longitude      0
# End Latitude       0
# Start Longitude    0
# Start Latitude     0
# Duration           0
# Member type        0
# Start_Day          0
# Start_Month        0
# Start_Hour         0
# Start_Min          0
# Start_week         0
# End_Day            0
# End_Month          0
# End_Hour           0
# End_Min            0
# End_week           0
# dtype: int64

# %%
trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314840 entries, 0 to 360030
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   End Longitude    314840 non-null  float64
#  1   End Latitude     314840 non-null  float64
#  2   Start Longitude  314840 non-null  float64
#  3   Start Latitude   314840 non-null  float64
#  4   Duration         314840 non-null  float64
#  5   Member type      314840 non-null  object
#  6   Start_Day        314840 non-null  int64
#  7   Start_Month      314840 non-null  int64
#  8   Start_Hour       314840 non-null  int64
#  9   Start_Min        314840 non-null  int64
#  10  Start_week       314840 non-null  int64
#  11  End_Day          314840 non-null  int64
#  12  End_Month        314840 non-null  float64
#  13  End_Hour         314840 non-null  int64
#  14  End_Min          314840 non-null  int64
#  15  End_week         314840 non-null  int64
# ...

# %%
https://chat.whatsapp.com/ISjpnC1CiIG0CEYMx82kqw
READWORKS.COM

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

X=trip.drop(['Member type'],axis=1)
Y=trip['Member type']
#Spliting
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

#Scaling
scaler=StandardScaler()
x_scaled_train=scaler.fit_transform(x_train)
x_scaled_test=scaler.transform(x_test)

X_train=pd.DataFrame(x_scaled_train,columns=x_train.columns)
X_test=pd.DataFrame(x_scaled_test,columns=x_test.columns)

#print(x_test)

from sklearn.feature_selection import VarianceThreshold
var_thresh=VarianceThreshold(threshold=0.0)
var_thresh.fit(x_scaled_train)
var_thresh.get_support() 

constant=[columns for columns in X_train.columns if columns not in X_train.columns[var_thresh.get_support()]]
print(len(constant))

X_train=X_train.drop(constant,axis=1)
X_test=X_test.drop(constant,axis=1)

#Heatmap to for correlation
import matplotlib.pyplot as plt
import seaborn as sns

def correlation(data,thres):
    corrs=set()
    corr_matrix=data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>thres:
                colname=corr_matrix.columns[i]
                corrs.add(colname)
    return corrs
corr_features=correlation(X_train,0.90)

X_train=X_train.drop(corr_features,axis=1)
X_test=X_test.drop(corr_features,axis=1)
X_train
# Out:
# '\n#Scaling\nscaler=StandardScaler()\nx_scaled_train=scaler.fit_transform(x_train)\nx_scaled_test=scaler.transform(x_test)\n\nX_train=pd.DataFrame(x_scaled_train,columns=x_train.columns)\nX_test=pd.DataFrame(x_scaled_test,columns=x_test.columns)\n\n#print(x_test)\n\nfrom sklearn.feature_selection import VarianceThreshold\nvar_thresh=VarianceThreshold(threshold=0.0)\nvar_thresh.fit(x_scaled_train)\nvar_thresh.get_support() \n\nconstant=[columns for columns in X_train.columns if columns not in X_train.columns[var_thresh.get_support()]]\nprint(len(constant))\n\nX_train=X_train.drop(constant,axis=1)\nX_test=X_test.drop(constant,axis=1)\n\n#Heatmap to for correlation\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\ndef correlation(data,thres):\n    corrs=set()\n    corr_matrix=data.corr()\n    for i in range(len(corr_matrix.columns)):\n        for j in range(i):\n            if abs(corr_matrix.iloc[i,j])>thres:\n                colname=corr_matrix.columns[i]\n                cor
# ...

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Logistic Reg before data imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

LR=LogisticRegression().fit(X_train,y_train)
train_predict=LR.predict(X_train)
test_predict=LR.predict(X_test)
print(LR.score(X_train,y_train))
print(LR.score(X_test,y_test))

print(classification_report(y_train,train_predict))
print(classification_report(y_test,test_predict))
# Out:
# 0.8677741074831661
# 0.8670541650785584
#               precision    recall  f1-score   support
#
#       Casual       0.41      0.05      0.08     28547
#       Member       0.87      0.99      0.93    191841
#
#     accuracy                           0.87    220388
#    macro avg       0.64      0.52      0.51    220388
# weighted avg       0.81      0.87      0.82    220388
#
#               precision    recall  f1-score   support
#
#       Casual       0.45      0.05      0.09     12412
#       Member       0.87      0.99      0.93     82040
#
#     accuracy                           0.87     94452
#    macro avg       0.66      0.52      0.51     94452
# weighted avg       0.82      0.87      0.82     94452

# %%
#Checking for Any imbalance in data
Y.value_counts()
# Out:
# 1    308767
# 0     51277
# Name: Member type, dtype: int64

# %%
#Making data balance

from imblearn.over_sampling import RandomOverSampler,SMOTE

sample=RandomOverSampler(random_state=42)
X_sampled,Y_sampled=sample.fit_resample(X_train,y_train)

smote=SMOTE(random_state=42)
X_resampled,Y_resampled=smote.fit_resample(X_train,y_train)

# %% [markdown]
# ### Logistic Reg after handling imbalance

# %%
Log=LogisticRegression().fit(X_sampled,Y_sampled)
train_predicts=Log.predict(X_sampled)
test_predicts=Log.predict(X_test)
print(Log.score(X_sampled,Y_sampled))
print(Log.score(X_test,y_test))

print(classification_report(Y_resampled,train_predicts))
print(classification_report(y_test,test_predicts))
# Out:
# Using TensorFlow backend.
# C:\Users\W R VARUN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\W R VARUN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\W R VARUN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ### XGBOOST

# %%
import xgboost

boost=xgboost.XGBClassifier(n_estimators=500,max_depth=7,learning_rate=0.01,booster='gbtree').fit(X_resampled,Y_resampled)
pred_train1=boost.predict(X_resampled)
pred_test1=boost.predict(X_test)
#print(boost.score(X_resampled,Y_resampled))
#print(boost.score(X_test,y_test))
print(classification_report(Y_resampled,pred_train1))
print(classification_report(y_test,pred_test1))
# Out:
#               precision    recall  f1-score   support
#
#       Casual       0.83      0.85      0.84    191841
#       Member       0.85      0.83      0.84    191841
#
#     accuracy                           0.84    383682
#    macro avg       0.84      0.84      0.84    383682
# weighted avg       0.84      0.84      0.84    383682
#
#               precision    recall  f1-score   support
#
#       Casual       0.35      0.64      0.45     12412
#       Member       0.94      0.82      0.88     82040
#
#     accuracy                           0.80     94452
#    macro avg       0.65      0.73      0.67     94452
# weighted avg       0.86      0.80      0.82     94452

# %% [markdown]
# ### Linear SVC

# %%
from sklearn.svm import LinearSVC

svc=LinearSVC().fit(X_resampled,Y_resampled)
pred_train3=svc.predict(X_resampled)
pred_test3=svc.predict(X_test)
print(svc.score(X_resampled,Y_resampled))
print(svc.score(X_test,y_test))
print(classification_report(Y_resampled,pred_train3))
print(classification_report(y_test,pred_test3))
# Out:
# C:\Users\W R VARUN\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.6952174094069643
# 0.805784435350973
#               precision    recall  f1-score   support
#
#            0       0.78      0.54      0.64    216159
#            1       0.65      0.85      0.74    216159
#
#     accuracy                           0.70    432318
#    macro avg       0.72      0.70      0.69    432318
# weighted avg       0.72      0.70      0.69    432318
#
#               precision    recall  f1-score   support
#
#            0       0.37      0.54      0.44     15406
#            1       0.92      0.85      0.88     92608
#
#     accuracy                           0.81    108014
#    macro avg       0.65      0.69      0.66    108014
# weighted avg       0.84      0.81      0.82    108014

# %% [markdown]
# ### RandomForest

# %%
forest=RandomForestClassifier(n_estimators=600,max_depth=11,min_samples_leaf=7).fit(X_resampled,Y_resampled)

#forest=RandomForestClassifier().fit(X_resampled,Y_resampled)
pred_train2=forest.predict(X_resampled)
pred_test2=forest.predict(X_test)
#print(forest.score(X_resampled,Y_resampled))
#print(forest.score(X_test,y_test))
print(classification_report(Y_resampled,pred_train2))
print(classification_report(y_test,pred_test2))
# Out:
#               precision    recall  f1-score   support
#
#       Casual       0.79      0.81      0.80    191841
#       Member       0.81      0.78      0.80    191841
#
#     accuracy                           0.80    383682
#    macro avg       0.80      0.80      0.80    383682
# weighted avg       0.80      0.80      0.80    383682
#
#               precision    recall  f1-score   support
#
#       Casual       0.32      0.71      0.45     12412
#       Member       0.95      0.78      0.85     82040
#
#     accuracy                           0.77     94452
#    macro avg       0.64      0.74      0.65     94452
# weighted avg       0.86      0.77      0.80     94452

# %% [markdown]
# ## Choosing RandomForest as final model which is giving good accuracy.

# %%
from sklearn.metrics import roc_curve
y_new=y_test.copy()
pred=pred_test2.copy()
y_new=np.where(y_new=='Casual',0,1)
pred=np.where(pred=='Casual',0,1)

fpr,tpr,thresholds=roc_curve(y_new,pred)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RF')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
# Out:
# Text(0.5, 1.0, 'ROC Curve')
